# %%
import json
import numpy as np
import math
from collections import defaultdict
from enum import Enum
import csv
import pandas as pd

# %%
class Datasets(Enum):
    ALL = 0
    MIMIC_CXR = 1
    CHEXPERT = 2

# %%
MODELS = [
    "dygie-radgraph-base",
    "dygie-radgraph-biobert",
    "dygie-radgraph-bioclinicalbert",
    "dygie-radgraph-bluebert",
    "dygie-radgraph-pubmedbert",
]
ORIGINAL_MODEL = "dygie-radgraph-original"
RADGRAPH_CLASSES = [
    "CHAN-CON-AP",
    "CHAN-WOR",
    "CHAN-IMP",
    "CHAN-CON-RES",
    "CHAN-NC",
    "CHAN-DEV-AP",
    "CHAN-DEV-PLACE",
    "CHAN-DEV-DISA",
    "ANAT-DP",
    "OBS-DP",
    "OBS-U",
    "OBS-DA"
]
ORIGINAL_CLASSES = [
    "ANAT-DP",
    "OBS-DP",
    "OBS-U",
    "OBS-DA"
]
RADGRAPH_RELATION_CLASSES = ['modify', 'located_at', 'suggestive_of']

# %%
def load_graph(filename):
    graph = []
    with open(f'../../data/{filename}.json') as f:
        lines = f.readlines()
    graph = [json.loads(line) for line in lines]
    graph = {r["doc_key"]: r for r in graph}
    return graph

original_radgraph = load_graph('dygie_test_original')
radgraph_change = load_graph('dygie_test')

# %%
def print_metrics(metrics_dict, radgraph_classes):
    total_tps = 0
    total_fps = 0
    total_fns = 0
    macro_precision = 0
    macro_recall = 0
    macro_f1 = 0
    for radgraph_class in radgraph_classes:
        tps = np.float64(metrics_dict[radgraph_class]['tps'])
        total_tps += tps
        fps = np.float64(metrics_dict[radgraph_class]['fps'])
        total_fps += fps
        fns = np.float64(metrics_dict[radgraph_class]['fns'])
        total_fns += fns
        total_actual = metrics_dict[radgraph_class]['total_actual']
        total_predicted = metrics_dict[radgraph_class]['total_predicted']
        precision = tps / (tps + fps)
        macro_precision += np.nan_to_num(precision, nan=0)
        recall = tps / (tps + fns)
        macro_recall += np.nan_to_num(recall, nan=0)
        f1 = 2 * precision * recall / (precision + recall)
        macro_f1 += np.nan_to_num(f1, nan=0)
        print(f"* Class {radgraph_class}")
        print(f"  - Precision: {precision}")
        print(f"  - Recall: {recall}")
        print(f"  - F1: {f1}")
        print(f"  - Total actual: {total_actual}")
        print(f"  - Total predicted: {total_predicted}")
    micro_precision = total_tps / (total_tps + total_fps)
    micro_recall = total_tps / (total_tps + total_fns)
    micro_f1 = 2 * micro_precision * micro_recall / (micro_precision + micro_recall)
    macro_precision /= len(radgraph_classes)
    macro_recall /= len(radgraph_classes)
    macro_f1 /= len(radgraph_classes)
    print(f"* Micro precision: {micro_precision}")
    print(f"* Micro recall: {micro_recall}")
    print(f"* Micro F1: {micro_f1}")
    print(f"* Macro precision: {macro_precision}")
    print(f"* Macro recall: {macro_recall}")
    print(f"* Macro F1: {macro_f1}")

# %%
def to_tuples_set(array):
    return {tuple(e) for e in array}

def add_statistics(metrics_dict, radgraph_class, ner_labels_of_class, ner_predictions_of_class):
    metrics_dict[radgraph_class]['tps'] += len(ner_labels_of_class & ner_predictions_of_class)
    metrics_dict[radgraph_class]['fps'] += len(ner_predictions_of_class - ner_labels_of_class)
    metrics_dict[radgraph_class]['fns'] += len(ner_labels_of_class - ner_predictions_of_class)
    metrics_dict[radgraph_class]['total_actual'] += len(ner_labels_of_class)
    metrics_dict[radgraph_class]['total_predicted'] += len(ner_predictions_of_class)

def evaluate(model_name, evaluate_original=False, model_original=False, dataset=Datasets.ALL):
    print(f"———————————————————[ Evaluating {model_name} ]———————————————————")
    with open(f'../../models/{model_name}/test_predictions.jsonl', 'r') as f:
        lines = f.readlines()
    model_predictions = [json.loads(line) for line in lines]
    
    ner_metrics_dict = defaultdict(lambda: {'tps': 0, 'fps': 0, 'fns': 0, 'total_actual': 0, 'total_predicted': 0})
    relations_metrics_dict = defaultdict(lambda: {'tps': 0, 'fps': 0, 'fns': 0, 'total_actual': 0, 'total_predicted': 0})
    
    for data_sample in model_predictions:
        if dataset is not Datasets.ALL:
            if dataset is Datasets.MIMIC_CXR and "/" not in data_sample["doc_key"]:
                continue
            elif dataset is Datasets.CHEXPERT and "/" in data_sample["doc_key"]:
                continue
        
        if evaluate_original:
            ner_classes = ORIGINAL_CLASSES
            
            change_ner_labels = to_tuples_set(radgraph_change[data_sample["doc_key"]]['ner'][0])
            original_ner_labels = to_tuples_set(original_radgraph[data_sample["doc_key"]]['ner'][0])
            ner_labels = change_ner_labels & original_ner_labels
            if not model_original:
                ignored_ner = change_ner_labels - ner_labels
            else:
                ignored_ner = original_ner_labels - ner_labels
                
            change_relation_labels = to_tuples_set(radgraph_change[data_sample["doc_key"]]['relations'][0])
            original_relation_labels = to_tuples_set(original_radgraph[data_sample["doc_key"]]['relations'][0])
            relation_labels = change_relation_labels & original_relation_labels
            if not model_original:
                ignored_relations = change_relation_labels - relation_labels
            else:
                ignored_relations = original_ner_labels - relation_labels
        else:
            ner_classes = RADGRAPH_CLASSES
            ner_labels = to_tuples_set(data_sample['ner'][0])
            ignored_ner = set()
            relation_labels = to_tuples_set(data_sample['relations'][0])
            ignored_relations = set()

        ner_predictions = to_tuples_set([prediction[:3] for prediction in data_sample['predicted_ner'][0]])
        relation_predictions = to_tuples_set([prediction[:5] for prediction in data_sample['predicted_relations'][0]])
        
        for radgraph_class in ner_classes:
            ner_labels_of_class = {l for l in ner_labels if l[2] == radgraph_class}
            ner_predictions_of_class = {p for p in ner_predictions if p[2] == radgraph_class and p not in ignored_ner}
            add_statistics(ner_metrics_dict, radgraph_class, ner_labels_of_class, ner_predictions_of_class)
            
        for radgraph_class in RADGRAPH_RELATION_CLASSES:
            relation_labels_of_class = {l for l in relation_labels if l[4] == radgraph_class}
            relation_predictions_of_class = {p for p in relation_predictions if p[4] == radgraph_class and p not in ignored_relations}
            add_statistics(relations_metrics_dict, radgraph_class, relation_labels_of_class, relation_predictions_of_class)
       
    print("NER results")
    print_metrics(ner_metrics_dict, ner_classes)
    print()
    print("Relations results")
    print_metrics(relations_metrics_dict, RADGRAPH_RELATION_CLASSES)
    print()
    print()

# %% [markdown]
# ## General evaluation results

# %%
for model in MODELS:
    evaluate(model)
# Out:
# ———————————————————[ Evaluating dygie-radgraph-base ]———————————————————
# NER results
# * Class CHAN-CON-AP
#   - Precision: 1.0
#   - Recall: 0.6666666666666666
#   - F1: 0.8
#   - Total actual: 6
#   - Total predicted: 4
# * Class CHAN-WOR
#   - Precision: 0.7037037037037037
#   - Recall: 0.9047619047619048
#   - F1: 0.7916666666666667
#   - Total actual: 21
#   - Total predicted: 27
# * Class CHAN-IMP
#   - Precision: 1.0
#   - Recall: 0.8181818181818182
#   - F1: 0.9
#   - Total actual: 11
#   - Total predicted: 9
# * Class CHAN-CON-RES
#   - Precision: 0.3333333333333333
#   - Recall: 1.0
#   - F1: 0.5
#   - Total actual: 1
#   - Total predicted: 3
# * Class CHAN-NC
#   - Precision: 0.9243697478991597
#   - Recall: 0.8527131782945736
#   - F1: 0.8870967741935484
#   - Total actual: 129
#   - Total predicted: 119
# * Class CHAN-DEV-AP
#   - Precision: 1.0
#   - Recall: 0.4
#   - F1: 0.5714285714285715
#   - Total actual: 5
#   - Total predicted: 2
# * Class CHAN-DEV-PLACE
#   - Precision: 1.0
#   - Recall: 1.0
#   - F1: 1.0
#   - Total actual: 1
#   - Total predicted: 1
# * Class CHAN-DEV-DISA
#   - Precision: 1.0
#   - Recall: 1.0
#   - F1: 1.0
#   - Total actual: 7
#   - Total predicted: 7
# * Class ANAT-DP
#   - Precision: 0.9409780775716695
#   - Recall: 0.9538461538461539
#   - F1: 0.9473684210526316
#   - Total actual: 1170
#   - Total predicted: 1186
# * Class OBS-DP
#   - Precision: 0.8645621181262729
#   - Recall: 0.8680981595092024
#   - F1: 0.8663265306122448
#   - Total actual: 978
#   - Total predicted: 982
# * Class OBS-U
#   - Precision: 0.7228915662650602
#   - Recall: 0.6818181818181818
#   - F1: 0.7017543859649122
#   - Total actual: 88
#   - Total predicted: 83
# * Class OBS-DA
#   - Precision: 0.927536231884058
#   - Recall: 0.9458128078817734
#   - F1: 0.9365853658536586
#   - Total actual: 406
#   - Total predicted: 414
# * Micro precision: 0.9030666196686641
# * Micro recall: 0.9075451647183846
# * Micro F1: 0.9053003533568903
# * Macro precision: 0.868114564898605
# * Macro recall: 0.8409915725800229
# * Macro F1: 0.8251855596476863
#
# Relations results
# * Class modify
#   - Precision: 0.7466456195737964
#   - Recall: 0.7028231797919762
#   - F1: 0.7240719479525449
#   - Total actual: 1346
#   - Total predicted: 1267
# * Class located_at
#   - Precision: 0.7939042089985486
#   - Recall: 0.8164179104477612
#   - F1: 0.8050036791758647
#   - Total actual: 670
#   - Total predicted: 689
# * Class suggestive_of
#   - Precision: 0.6818181818181818
#   - Recall: 0.4838709677419355
#   - F1: 0.5660377358490567
#   - Total actual: 93
#   - Total predicted: 66
# * Micro precision: 0.7606330365974283
# * Micro recall: 0.7292555713608345
# * Micro F1: 0.7446138949406923
# * Macro precision: 0.7407893367968422
# * Macro recall: 0.6677040193272243
# * Macro F1: 0.6983711209924888
#
#
# ———————————————————[ Evaluating dygie-radgraph-biobert ]———————————————————
# NER results
# * Class CHAN-CON-AP
#   - Precision: 0.6666666666666666
#   - Recall: 0.6666666666666666
#   - F1: 0.6666666666666666
#   - Total actual: 6
#   - Total predicted: 6
# * Class CHAN-WOR
#   - Precision: 0.7142857142857143
#   - Recall: 0.9523809523809523
#   - F1: 0.8163265306122449
#   - Total actual: 21
#   - Total predicted: 28
# * Class CHAN-IMP
#   - Precision: 0.7857142857142857
#   - Recall: 1.0
#   - F1: 0.88
#   - Total actual: 11
#   - Total predicted: 14
# * Class CHAN-CON-RES
#   - Precision: 0.5
#   - Recall: 1.0
#   - F1: 0.6666666666666666
#   - Total actual: 1
#   - Total predicted: 2
# * Class CHAN-NC
#   - Precision: 0.9401709401709402
#   - Recall: 0.8527131782945736
#   - F1: 0.8943089430894308
#   - Total actual: 129
#   - Total predicted: 117
# * Class CHAN-DEV-AP
#   - Precision: 0.3333333333333333
#   - Recall: 0.2
#   - F1: 0.25
#   - Total actual: 5
#   - Total predicted: 3
# * Class CHAN-DEV-PLACE
#   - Precision: nan
#   - Recall: 0.0
#   - F1: nan
#   - Total actual: 1
#   - Total predicted: 0
# * Class CHAN-DEV-DISA
#   - Precision: 1.0
#   - Recall: 1.0
#   - F1: 1.0
#   - Total actual: 7
#   - Total predicted: 7
# * Class ANAT-DP
#   - Precision: 0.9528301886792453
#   - Recall: 0.9495726495726495
#   - F1: 0.9511986301369861
#   - Total actual: 1170
#   - Total predicted: 1166
# * Class OBS-DP
#   - Precision: 0.844488188976378
#   - Recall: 0.8773006134969326
#   - F1: 0.8605817452357072
#   - Total actual: 978
#   - Total predicted: 1016
# * Class OBS-U
#   - Precision: 0.6226415094339622
#   - Recall: 0.75
#   - F1: 0.6804123711340205
#   - Total actual: 88
#   - Total predicted: 106
# * Class OBS-DA
#   - Precision: 0.9556650246305419
#   - Recall: 0.9556650246305419
#   - F1: 0.9556650246305419
#   - Total actual: 406
#   - Total predicted: 406
# * Micro precision: 0.8975966562173459
# * Micro recall: 0.9128586609989373
# * Micro F1: 0.9051633298208641
# * Macro precision: 0.6929829876575889
# * Macro recall: 0.7670249237535264
# * Macro F1: 0.7184855481810221
#
# Relations results
# * Class modify
#   - Precision: 0.7339300244100895
#   - Recall: 0.7175815433571997
#   - F1: 0.7256637168141593
#   - Total actual: 1257
#   - Total predicted: 1229
# * Class located_at
#   - Precision: 0.7274052478134111
#   - Recall: 0.810064935064935
#   - F1: 0.7665130568356374
#   - Total actual: 616
#   - Total predicted: 686
# * Class suggestive_of
#   - Precision: 0.7534246575342466
#   - Recall: 0.6395348837209303
#   - F1: 0.6918238993710691
#   - Total actual: 86
#   - Total predicted: 73
# * Micro precision: 0.7323943661971831
# * Micro recall: 0.7432363450740174
# * Micro F1: 0.7377755257157336
# * Macro precision: 0.7382533099192491
# * Macro recall: 0.7223937873810217
# * Macro F1: 0.7280002243402887
#
#
# ———————————————————[ Evaluating dygie-radgraph-bioclinicalbert ]———————————————————
# NER results
# * Class CHAN-CON-AP
#   - Precision: 1.0
#   - Recall: 0.8333333333333334
#   - F1: 0.9090909090909091
#   - Total actual: 6
#   - Total predicted: 5
# * Class CHAN-WOR
#   - Precision: 0.7692307692307693
#   - Recall: 0.9523809523809523
#   - F1: 0.8510638297872339
#   - Total actual: 21
#   - Total predicted: 26
# * Class CHAN-IMP
#   - Precision: 0.9166666666666666
#   - Recall: 1.0
#   - F1: 0.9565217391304348
#   - Total actual: 11
#   - Total predicted: 12
# * Class CHAN-CON-RES
#   - Precision: 0.5
#   - Recall: 1.0
#   - F1: 0.6666666666666666
#   - Total actual: 1
#   - Total predicted: 2
# * Class CHAN-NC
#   - Precision: 0.9112903225806451
#   - Recall: 0.875968992248062
#   - F1: 0.893280632411067
#   - Total actual: 129
#   - Total predicted: 124
# * Class CHAN-DEV-AP
#   - Precision: 1.0
#   - Recall: 0.4
#   - F1: 0.5714285714285715
#   - Total actual: 5
#   - Total predicted: 2
# * Class CHAN-DEV-PLACE
#   - Precision: nan
#   - Recall: 0.0
#   - F1: nan
#   - Total actual: 1
#   - Total predicted: 0
# * Class CHAN-DEV-DISA
#   - Precision: 1.0
#   - Recall: 1.0
#   - F1: 1.0
#   - Total actual: 7
#   - Total predicted: 7
# * Class ANAT-DP
#   - Precision: 0.9514066496163683
#   - Recall: 0.9538461538461539
#   - F1: 0.9526248399487837
#   - Total actual: 1170
#   - Total predicted: 1173
# * Class OBS-DP
#   - Precision: 0.90041928721174
#   - Recall: 0.878323108384458
#   - F1: 0.8892339544513458
#   - Total actual: 978
#   - Total predicted: 954
# * Class OBS-U
#   - Precision: 0.6767676767676768
#   - Recall: 0.7613636363636364
#   - F1: 0.7165775401069518
#   - Total actual: 88
#   - Total predicted: 99
# * Class OBS-DA
#   - Precision: 0.9459459459459459
#   - Recall: 0.9482758620689655
#   - F1: 0.947109471094711
#   - Total actual: 406
#   - Total predicted: 407
# * Micro precision: 0.919957310565635
# * Micro recall: 0.9160467587672688
# * Micro F1: 0.9179978700745474
# * Macro precision: 0.7976439431683177
# * Macro recall: 0.8002910032187969
# * Macro F1: 0.7794665128430562
#
# Relations results
# * Class modify
#   - Precision: 0.7966666666666666
#   - Recall: 0.7102526002971769
#   - F1: 0.750981932443048
#   - Total actual: 1346
#   - Total predicted: 1200
# * Class located_at
#   - Precision: 0.7893217893217893
#   - Recall: 0.8164179104477612
#   - F1: 0.8026412325752018
#   - Total actual: 670
#   - Total predicted: 693
# * Class suggestive_of
#   - Precision: 0.6987951807228916
#   - Recall: 0.6236559139784946
#   - F1: 0.6590909090909091
#   - Total actual: 93
#   - Total predicted: 83
# * Micro precision: 0.7899797570850202
# * Micro recall: 0.7401612138454243
# * Micro F1: 0.7642594859241126
# * Macro precision: 0.7615945455704493
# * Macro recall: 0.7167754749078109
# * Macro F1: 0.7375713580363863
#
#
# ———————————————————[ Evaluating dygie-radgraph-bluebert ]———————————————————
# NER results
# * Class CHAN-CON-AP
#   - Precision: 1.0
#   - Recall: 0.6666666666666666
#   - F1: 0.8
#   - Total actual: 6
#   - Total predicted: 4
# * Class CHAN-WOR
#   - Precision: 0.7037037037037037
#   - Recall: 0.9047619047619048
#   - F1: 0.7916666666666667
#   - Total actual: 21
#   - Total predicted: 27
# * Class CHAN-IMP
#   - Precision: 0.8461538461538461
#   - Recall: 1.0
#   - F1: 0.9166666666666666
#   - Total actual: 11
#   - Total predicted: 13
# * Class CHAN-CON-RES
#   - Precision: 1.0
#   - Recall: 1.0
#   - F1: 1.0
#   - Total actual: 1
#   - Total predicted: 1
# * Class CHAN-NC
#   - Precision: 0.904
#   - Recall: 0.875968992248062
#   - F1: 0.889763779527559
#   - Total actual: 129
#   - Total predicted: 125
# * Class CHAN-DEV-AP
#   - Precision: 1.0
#   - Recall: 0.8
#   - F1: 0.888888888888889
#   - Total actual: 5
#   - Total predicted: 4
# * Class CHAN-DEV-PLACE
#   - Precision: nan
#   - Recall: 0.0
#   - F1: nan
#   - Total actual: 1
#   - Total predicted: 0
# * Class CHAN-DEV-DISA
#   - Precision: 1.0
#   - Recall: 0.8571428571428571
#   - F1: 0.923076923076923
#   - Total actual: 7
#   - Total predicted: 6
# * Class ANAT-DP
#   - Precision: 0.9484978540772532
#   - Recall: 0.9444444444444444
#   - F1: 0.9464668094218415
#   - Total actual: 1170
#   - Total predicted: 1165
# * Class OBS-DP
#   - Precision: 0.8479763079960513
#   - Recall: 0.878323108384458
#   - F1: 0.862882973380211
#   - Total actual: 978
#   - Total predicted: 1013
# * Class OBS-U
#   - Precision: 0.5538461538461539
#   - Recall: 0.8181818181818182
#   - F1: 0.6605504587155965
#   - Total actual: 88
#   - Total predicted: 130
# * Class OBS-DA
#   - Precision: 0.9247572815533981
#   - Recall: 0.9384236453201971
#   - F1: 0.9315403422982886
#   - Total actual: 406
#   - Total predicted: 412
# * Micro precision: 0.8879310344827587
# * Micro recall: 0.9121501948281969
# * Micro F1: 0.8998776865280448
# * Macro precision: 0.8107445956108673
# * Macro recall: 0.8069927864292006
# * Macro F1: 0.8009586257202201
#
# Relations results
# * Class modify
#   - Precision: 0.7404458598726115
#   - Recall: 0.6909361069836553
#   - F1: 0.7148347425057648
#   - Total actual: 1346
#   - Total predicted: 1256
# * Class located_at
#   - Precision: 0.7706552706552706
#   - Recall: 0.8074626865671641
#   - F1: 0.7886297376093294
#   - Total actual: 670
#   - Total predicted: 702
# * Class suggestive_of
#   - Precision: 0.6486486486486487
#   - Recall: 0.5161290322580645
#   - F1: 0.5748502994011976
#   - Total actual: 93
#   - Total predicted: 74
# * Micro precision: 0.7475393700787402
# * Micro recall: 0.7202465623518255
# * Micro F1: 0.7336392175802945
# * Macro precision: 0.7199165930588437
# * Macro recall: 0.6715092752696279
# * Macro F1: 0.6927715931720972
#
#
# ———————————————————[ Evaluating dygie-radgraph-pubmedbert ]———————————————————
# NER results
# * Class CHAN-CON-AP
#   - Precision: 0.6666666666666666
#   - Recall: 0.6666666666666666
#   - F1: 0.6666666666666666
#   - Total actual: 6
#   - Total predicted: 6
# * Class CHAN-WOR
#   - Precision: 0.5135135135135135
#   - Recall: 0.9047619047619048
#   - F1: 0.6551724137931034
#   - Total actual: 21
#   - Total predicted: 37
# * Class CHAN-IMP
#   - Precision: 0.9090909090909091
#   - Recall: 0.9090909090909091
#   - F1: 0.9090909090909091
#   - Total actual: 11
#   - Total predicted: 11
# * Class CHAN-CON-RES
#   - Precision: 0.0
#   - Recall: 0.0
#   - F1: nan
#   - Total actual: 1
#   - Total predicted: 1
# * Class CHAN-NC
#   - Precision: 0.9069767441860465
#   - Recall: 0.9069767441860465
#   - F1: 0.9069767441860465
#   - Total actual: 129
#   - Total predicted: 129
# * Class CHAN-DEV-AP
#   - Precision: 0.0
#   - Recall: 0.0
#   - F1: nan
#   - Total actual: 5
#   - Total predicted: 1
# * Class CHAN-DEV-PLACE
#   - Precision: nan
#   - Recall: 0.0
#   - F1: nan
#   - Total actual: 1
#   - Total predicted: 0
# * Class CHAN-DEV-DISA
#   - Precision: 1.0
#   - Recall: 1.0
#   - F1: 1.0
#   - Total actual: 7
#   - Total predicted: 7
# * Class ANAT-DP
#   - Precision: 0.9555175363558597
#   - Recall: 0.9547008547008548
#   - F1: 0.9551090209491235
#   - Total actual: 1170
#   - Total predicted: 1169
# * Class OBS-DP
#   - Precision: 0.7170445004198153
#   - Recall: 0.8732106339468303
#   - F1: 0.7874596588289534
#   - Total actual: 978
#   - Total predicted: 1191
# * Class OBS-U
#   - Precision: 0.6451612903225806
#   - Recall: 0.6818181818181818
#   - F1: 0.6629834254143646
#   - Total actual: 88
#   - Total predicted: 93
# * Class OBS-DA
#   - Precision: 0.9411764705882353
#   - Recall: 0.9458128078817734
#   - F1: 0.9434889434889434
#   - Total actual: 406
#   - Total predicted: 408
# * Micro precision: 0.8424500491320013
# * Micro recall: 0.9110874955720865
# * Micro F1: 0.875425459496256
# * Macro precision: 0.6045956359286356
# * Macro recall: 0.6535865585877639
# * Macro F1: 0.6239123152015092
#
# Relations results
# * Class modify
#   - Precision: 0.7325072886297376
#   - Recall: 0.7466567607726597
#   - F1: 0.739514348785872
#   - Total actual: 1346
#   - Total predicted: 1372
# * Class located_at
#   - Precision: 0.8074074074074075
#   - Recall: 0.8134328358208955
#   - F1: 0.8104089219330854
#   - Total actual: 670
#   - Total predicted: 675
# * Class suggestive_of
#   - Precision: 0.6790123456790124
#   - Recall: 0.5913978494623656
#   - F1: 0.6321839080459771
#   - Total actual: 93
#   - Total predicted: 81
# * Micro precision: 0.7542293233082706
# * Micro recall: 0.7610241820768137
# * Micro F1: 0.7576115175831956
# * Macro precision: 0.7396423472387191
# * Macro recall: 0.7171624820186403
# * Macro F1: 0.7273690595883116
# /home/ad461/miniconda3/envs/radgraph-env/lib/python3.7/site-packages/ipykernel_launcher.py:17: RuntimeWarning: invalid value encountered in double_scalars
# /home/ad461/miniconda3/envs/radgraph-env/lib/python3.7/site-packages/ipykernel_launcher.py:21: RuntimeWarning: invalid value encountered in double_scalars

# %% [markdown]
# ## Head-to-head comparison

# %%
evaluate("dygie-radgraph-bioclinicalbert", evaluate_original=True, dataset=Datasets.MIMIC_CXR)
# Out:
# ———————————————————[ Evaluating dygie-radgraph-bioclinicalbert ]———————————————————
# NER results
# * Class ANAT-DP
#   - Precision: 0.955637707948244
#   - Recall: 0.9773156899810964
#   - F1: 0.9663551401869158
#   - Total actual: 529
#   - Total predicted: 541
# * Class OBS-DP
#   - Precision: 0.9006928406466512
#   - Recall: 0.8986175115207373
#   - F1: 0.8996539792387543
#   - Total actual: 434
#   - Total predicted: 433
# * Class OBS-U
#   - Precision: 0.725
#   - Recall: 0.7073170731707317
#   - F1: 0.7160493827160495
#   - Total actual: 41
#   - Total predicted: 40
# * Class OBS-DA
#   - Precision: 0.9426229508196722
#   - Recall: 0.9623430962343096
#   - F1: 0.9523809523809523
#   - Total actual: 239
#   - Total predicted: 244
# * Micro precision: 0.9268680445151033
# * Micro recall: 0.9380530973451328
# * Micro F1: 0.9324270291883247
# * Macro precision: 0.8809883748536418
# * Macro recall: 0.8863983427267187
# * Macro F1: 0.883609863630668
#
# Relations results
# * Class modify
#   - Precision: 0.8271844660194175
#   - Recall: 0.8145315487571702
#   - F1: 0.8208092485549133
#   - Total actual: 523
#   - Total predicted: 515
# * Class located_at
#   - Precision: 0.7988980716253443
#   - Recall: 0.8682634730538922
#   - F1: 0.8321377331420373
#   - Total actual: 334
#   - Total predicted: 363
# * Class suggestive_of
#   - Precision: 0.6
#   - Recall: 0.6666666666666666
#   - F1: 0.631578947368421
#   - Total actual: 27
#   - Total predicted: 30
# * Micro precision: 0.8083700440528634
# * Micro recall: 0.830316742081448
# * Micro F1: 0.8191964285714286
# * Macro precision: 0.7420275125482539
# * Macro recall: 0.7831538961592429
# * Macro F1: 0.7615086430217906

# %%
evaluate(ORIGINAL_MODEL, evaluate_original=True, model_original=True, dataset=Datasets.MIMIC_CXR)
# Out:
# ———————————————————[ Evaluating dygie-radgraph-original ]———————————————————
# NER results
# * Class ANAT-DP
#   - Precision: 0.9574074074074074
#   - Recall: 0.9773156899810964
#   - F1: 0.9672591206735266
#   - Total actual: 529
#   - Total predicted: 540
# * Class OBS-DP
#   - Precision: 0.9207459207459208
#   - Recall: 0.9101382488479263
#   - F1: 0.9154113557358053
#   - Total actual: 434
#   - Total predicted: 429
# * Class OBS-U
#   - Precision: 0.7297297297297297
#   - Recall: 0.6585365853658537
#   - F1: 0.6923076923076923
#   - Total actual: 41
#   - Total predicted: 37
# * Class OBS-DA
#   - Precision: 0.9251968503937008
#   - Recall: 0.9832635983263598
#   - F1: 0.9533468559837729
#   - Total actual: 239
#   - Total predicted: 254
# * Micro precision: 0.9317460317460318
# * Micro recall: 0.9444891391794047
# * Micro F1: 0.9380743108270078
# * Macro precision: 0.8832699770691897
# * Macro recall: 0.8823135306303092
# * Macro F1: 0.8820812561751993
#
# Relations results
# * Class modify
#   - Precision: 0.8323809523809523
#   - Recall: 0.8355640535372849
#   - F1: 0.833969465648855
#   - Total actual: 523
#   - Total predicted: 525
# * Class located_at
#   - Precision: 0.8352601156069365
#   - Recall: 0.8652694610778443
#   - F1: 0.85
#   - Total actual: 334
#   - Total predicted: 346
# * Class suggestive_of
#   - Precision: 0.6551724137931034
#   - Recall: 0.7037037037037037
#   - F1: 0.6785714285714286
#   - Total actual: 27
#   - Total predicted: 29
# * Micro precision: 0.8277777777777777
# * Micro recall: 0.8427601809954751
# * Micro F1: 0.8352017937219731
# * Macro precision: 0.774271160593664
# * Macro recall: 0.8015124061062776
# * Macro F1: 0.7875136314067612

# %%
evaluate("dygie-radgraph-bioclinicalbert", evaluate_original=True, dataset=Datasets.CHEXPERT)
# Out:
# ———————————————————[ Evaluating dygie-radgraph-bioclinicalbert ]———————————————————
# NER results
# * Class ANAT-DP
#   - Precision: 0.9477848101265823
#   - Recall: 0.9344773790951638
#   - F1: 0.9410840534171249
#   - Total actual: 641
#   - Total predicted: 632
# * Class OBS-DP
#   - Precision: 0.9
#   - Recall: 0.861878453038674
#   - F1: 0.8805268109125118
#   - Total actual: 543
#   - Total predicted: 520
# * Class OBS-U
#   - Precision: 0.6440677966101694
#   - Recall: 0.8085106382978723
#   - F1: 0.7169811320754716
#   - Total actual: 47
#   - Total predicted: 59
# * Class OBS-DA
#   - Precision: 0.950920245398773
#   - Recall: 0.9281437125748503
#   - F1: 0.9393939393939393
#   - Total actual: 167
#   - Total predicted: 163
# * Micro precision: 0.9170305676855895
# * Micro recall: 0.9012875536480687
# * Micro F1: 0.9090909090909091
# * Macro precision: 0.8606932130338811
# * Macro recall: 0.8832525457516401
# * Macro F1: 0.869496483949762
#
# Relations results
# * Class modify
#   - Precision: 0.7589424572317263
#   - Recall: 0.6863572433192686
#   - F1: 0.7208271787296897
#   - Total actual: 711
#   - Total predicted: 643
# * Class located_at
#   - Precision: 0.7787878787878788
#   - Recall: 0.7648809523809523
#   - F1: 0.7717717717717717
#   - Total actual: 336
#   - Total predicted: 330
# * Class suggestive_of
#   - Precision: 0.7547169811320755
#   - Recall: 0.6060606060606061
#   - F1: 0.6722689075630252
#   - Total actual: 66
#   - Total predicted: 53
# * Micro precision: 0.7651072124756335
# * Micro recall: 0.7053009883198562
# * Micro F1: 0.7339878447872838
# * Macro precision: 0.7641491057172268
# * Macro recall: 0.685766267253609
# * Macro F1: 0.7216226193548289

# %%
evaluate(ORIGINAL_MODEL, evaluate_original=True, model_original=True, dataset=Datasets.CHEXPERT)
# Out:
# ———————————————————[ Evaluating dygie-radgraph-original ]———————————————————
# NER results
# * Class ANAT-DP
#   - Precision: 0.9416403785488959
#   - Recall: 0.9313572542901716
#   - F1: 0.9364705882352942
#   - Total actual: 641
#   - Total predicted: 634
# * Class OBS-DP
#   - Precision: 0.851985559566787
#   - Recall: 0.8692449355432781
#   - F1: 0.8605287146763901
#   - Total actual: 543
#   - Total predicted: 554
# * Class OBS-U
#   - Precision: 0.6129032258064516
#   - Recall: 0.8085106382978723
#   - F1: 0.6972477064220183
#   - Total actual: 47
#   - Total predicted: 62
# * Class OBS-DA
#   - Precision: 0.9325153374233128
#   - Recall: 0.9101796407185628
#   - F1: 0.9212121212121211
#   - Total actual: 167
#   - Total predicted: 163
# * Micro precision: 0.8910120311394196
# * Micro recall: 0.9005722460658083
# * Micro F1: 0.8957666310921379
# * Macro precision: 0.8347611253363618
# * Macro recall: 0.8798231172124712
# * Macro F1: 0.8538647826364558
#
# Relations results
# * Class modify
#   - Precision: 0.7380239520958084
#   - Recall: 0.6933895921237694
#   - F1: 0.7150108774474256
#   - Total actual: 711
#   - Total predicted: 668
# * Class located_at
#   - Precision: 0.7738095238095238
#   - Recall: 0.7738095238095238
#   - F1: 0.7738095238095238
#   - Total actual: 336
#   - Total predicted: 336
# * Class suggestive_of
#   - Precision: 0.84
#   - Recall: 0.6363636363636364
#   - F1: 0.7241379310344828
#   - Total actual: 66
#   - Total predicted: 50
# * Micro precision: 0.75426944971537
# * Micro recall: 0.7142857142857143
# * Micro F1: 0.7337332718043378
# * Macro precision: 0.7839444919684441
# * Macro recall: 0.7011875840989764
# * Macro F1: 0.7376527774304774

# %% [markdown]
# ## MIMIC-CXR Only

# %%
for model in MODELS:
    evaluate(model, dataset=Datasets.MIMIC_CXR)
# Out:
# ———————————————————[ Evaluating dygie-radgraph-base ]———————————————————
# NER results
# * Class CHAN-CON-AP
#   - Precision: 1.0
#   - Recall: 0.8
#   - F1: 0.888888888888889
#   - Total actual: 5
#   - Total predicted: 4
# * Class CHAN-WOR
#   - Precision: 0.42857142857142855
#   - Recall: 0.75
#   - F1: 0.5454545454545454
#   - Total actual: 4
#   - Total predicted: 7
# * Class CHAN-IMP
#   - Precision: 1.0
#   - Recall: 0.6666666666666666
#   - F1: 0.8
#   - Total actual: 6
#   - Total predicted: 4
# * Class CHAN-CON-RES
#   - Precision: 0.3333333333333333
#   - Recall: 1.0
#   - F1: 0.5
#   - Total actual: 1
#   - Total predicted: 3
# * Class CHAN-NC
#   - Precision: 0.9137931034482759
#   - Recall: 0.8833333333333333
#   - F1: 0.8983050847457628
#   - Total actual: 60
#   - Total predicted: 58
# * Class CHAN-DEV-AP
#   - Precision: nan
#   - Recall: nan
#   - F1: nan
#   - Total actual: 0
#   - Total predicted: 0
# * Class CHAN-DEV-PLACE
#   - Precision: nan
#   - Recall: nan
#   - F1: nan
#   - Total actual: 0
#   - Total predicted: 0
# * Class CHAN-DEV-DISA
#   - Precision: 1.0
#   - Recall: 1.0
#   - F1: 1.0
#   - Total actual: 2
#   - Total predicted: 2
# * Class ANAT-DP
#   - Precision: 0.9559633027522936
#   - Recall: 0.9848771266540642
#   - F1: 0.9702048417132216
#   - Total actual: 529
#   - Total predicted: 545
# * Class OBS-DP
#   - Precision: 0.9128329297820823
#   - Recall: 0.8666666666666667
#   - F1: 0.8891509433962265
#   - Total actual: 435
#   - Total predicted: 413
# * Class OBS-U
#   - Precision: 0.8125
#   - Recall: 0.6341463414634146
#   - F1: 0.7123287671232876
#   - Total actual: 41
#   - Total predicted: 32
# * Class OBS-DA
#   - Precision: 0.9357429718875502
#   - Recall: 0.9748953974895398
#   - F1: 0.9549180327868854
#   - Total actual: 239
#   - Total predicted: 249
# * Micro precision: 0.929384965831435
# * Micro recall: 0.9258698940998488
# * Micro F1: 0.9276241000378931
# * Macro precision: 0.6910614224812469
# * Macro recall: 0.7133821276894737
# * Macro F1: 0.6799375920090682
#
# Relations results
# * Class modify
#   - Precision: 0.8433962264150944
#   - Recall: 0.7693631669535284
#   - F1: 0.8046804680468047
#   - Total actual: 581
#   - Total predicted: 530
# * Class located_at
#   - Precision: 0.8146067415730337
#   - Recall: 0.8682634730538922
#   - F1: 0.8405797101449275
#   - Total actual: 334
#   - Total predicted: 356
# * Class suggestive_of
#   - Precision: 0.56
#   - Recall: 0.5185185185185185
#   - F1: 0.5384615384615384
#   - Total actual: 27
#   - Total predicted: 25
# * Micro precision: 0.8243688254665203
# * Micro recall: 0.79723991507431
# * Micro F1: 0.8105774419859687
# * Macro precision: 0.7393343226627094
# * Macro recall: 0.7187150528419797
# * Macro F1: 0.7279072388844235
#
#
# ———————————————————[ Evaluating dygie-radgraph-biobert ]———————————————————
# NER results
# * Class CHAN-CON-AP
#   - Precision: 1.0
#   - Recall: 0.8
#   - F1: 0.888888888888889
#   - Total actual: 5
#   - Total predicted: 4
# * Class CHAN-WOR
#   - Precision: 0.42857142857142855
#   - Recall: 0.75
#   - F1: 0.5454545454545454
#   - Total actual: 4
#   - Total predicted: 7
# * Class CHAN-IMP
#   - Precision: 0.8571428571428571
#   - Recall: 1.0
#   - F1: 0.923076923076923
#   - Total actual: 6
#   - Total predicted: 7
# * Class CHAN-CON-RES
#   - Precision: 0.5
#   - Recall: 1.0
#   - F1: 0.6666666666666666
#   - Total actual: 1
#   - Total predicted: 2
# * Class CHAN-NC
#   - Precision: 0.9272727272727272
#   - Recall: 0.85
#   - F1: 0.8869565217391303
#   - Total actual: 60
#   - Total predicted: 55
# * Class CHAN-DEV-AP
#   - Precision: nan
#   - Recall: nan
#   - F1: nan
#   - Total actual: 0
#   - Total predicted: 0
# * Class CHAN-DEV-PLACE
#   - Precision: nan
#   - Recall: nan
#   - F1: nan
#   - Total actual: 0
#   - Total predicted: 0
# * Class CHAN-DEV-DISA
#   - Precision: 1.0
#   - Recall: 1.0
#   - F1: 1.0
#   - Total actual: 2
#   - Total predicted: 2
# * Class ANAT-DP
#   - Precision: 0.9591078066914498
#   - Recall: 0.9754253308128544
#   - F1: 0.9671977507029054
#   - Total actual: 529
#   - Total predicted: 538
# * Class OBS-DP
#   - Precision: 0.9196217494089834
#   - Recall: 0.8942528735632184
#   - F1: 0.9067599067599067
#   - Total actual: 435
#   - Total predicted: 423
# * Class OBS-U
#   - Precision: 0.7435897435897436
#   - Recall: 0.7073170731707317
#   - F1: 0.725
#   - Total actual: 41
#   - Total predicted: 39
# * Class OBS-DA
#   - Precision: 0.9551020408163265
#   - Recall: 0.9790794979079498
#   - F1: 0.9669421487603306
#   - Total actual: 239
#   - Total predicted: 245
# * Micro precision: 0.9341906202723147
# * Micro recall: 0.9341906202723147
# * Micro F1: 0.9341906202723147
# * Macro precision: 0.6908673627911264
# * Macro recall: 0.7463395646212295
# * Macro F1: 0.706411946004108
#
# Relations results
# * Class modify
#   - Precision: 0.7509363295880149
#   - Recall: 0.7756286266924565
#   - F1: 0.7630827783063749
#   - Total actual: 517
#   - Total predicted: 534
# * Class located_at
#   - Precision: 0.7197802197802198
#   - Recall: 0.8733333333333333
#   - F1: 0.7891566265060241
#   - Total actual: 300
#   - Total predicted: 364
# * Class suggestive_of
#   - Precision: 0.5714285714285714
#   - Recall: 0.6956521739130435
#   - F1: 0.6274509803921569
#   - Total actual: 23
#   - Total predicted: 28
# * Micro precision: 0.7332613390928726
# * Micro recall: 0.8083333333333333
# * Micro F1: 0.7689694224235561
# * Macro precision: 0.680715040265602
# * Macro recall: 0.7815380446462777
# * Macro F1: 0.7265634617348521
#
#
# ———————————————————[ Evaluating dygie-radgraph-bioclinicalbert ]———————————————————
# NER results
# * Class CHAN-CON-AP
#   - Precision: 1.0
#   - Recall: 1.0
#   - F1: 1.0
#   - Total actual: 5
#   - Total predicted: 5
# * Class CHAN-WOR
#   - Precision: 0.6
#   - Recall: 0.75
#   - F1: 0.6666666666666665
#   - Total actual: 4
#   - Total predicted: 5
# * Class CHAN-IMP
#   - Precision: 0.8571428571428571
#   - Recall: 1.0
#   - F1: 0.923076923076923
#   - Total actual: 6
#   - Total predicted: 7
# * Class CHAN-CON-RES
#   - Precision: 0.5
#   - Recall: 1.0
#   - F1: 0.6666666666666666
#   - Total actual: 1
#   - Total predicted: 2
# * Class CHAN-NC
#   - Precision: 0.896551724137931
#   - Recall: 0.8666666666666667
#   - F1: 0.8813559322033899
#   - Total actual: 60
#   - Total predicted: 58
# * Class CHAN-DEV-AP
#   - Precision: nan
#   - Recall: nan
#   - F1: nan
#   - Total actual: 0
#   - Total predicted: 0
# * Class CHAN-DEV-PLACE
#   - Precision: nan
#   - Recall: nan
#   - F1: nan
#   - Total actual: 0
#   - Total predicted: 0
# * Class CHAN-DEV-DISA
#   - Precision: 1.0
#   - Recall: 1.0
#   - F1: 1.0
#   - Total actual: 2
#   - Total predicted: 2
# * Class ANAT-DP
#   - Precision: 0.955637707948244
#   - Recall: 0.9773156899810964
#   - F1: 0.9663551401869158
#   - Total actual: 529
#   - Total predicted: 541
# * Class OBS-DP
#   - Precision: 0.9009216589861752
#   - Recall: 0.8988505747126436
#   - F1: 0.8998849252013809
#   - Total actual: 435
#   - Total predicted: 434
# * Class OBS-U
#   - Precision: 0.725
#   - Recall: 0.7073170731707317
#   - F1: 0.7160493827160495
#   - Total actual: 41
#   - Total predicted: 40
# * Class OBS-DA
#   - Precision: 0.9426229508196722
#   - Recall: 0.9623430962343096
#   - F1: 0.9523809523809523
#   - Total actual: 239
#   - Total predicted: 244
# * Micro precision: 0.9237668161434978
# * Micro recall: 0.9349470499243571
# * Micro F1: 0.9293233082706768
# * Macro precision: 0.6981564082529066
# * Macro recall: 0.763541091730454
# * Macro F1: 0.7227030490915786
#
# Relations results
# * Class modify
#   - Precision: 0.8348794063079777
#   - Recall: 0.774526678141136
#   - F1: 0.8035714285714285
#   - Total actual: 581
#   - Total predicted: 539
# * Class located_at
#   - Precision: 0.7988980716253443
#   - Recall: 0.8682634730538922
#   - F1: 0.8321377331420373
#   - Total actual: 334
#   - Total predicted: 363
# * Class suggestive_of
#   - Precision: 0.6
#   - Recall: 0.6666666666666666
#   - F1: 0.631578947368421
#   - Total actual: 27
#   - Total predicted: 30
# * Micro precision: 0.8133047210300429
# * Micro recall: 0.8046709129511678
# * Micro F1: 0.8089647812166489
# * Macro precision: 0.7445924926444407
# * Macro recall: 0.7698189392872316
# * Macro F1: 0.7557627030272956
#
#
# ———————————————————[ Evaluating dygie-radgraph-bluebert ]———————————————————
# NER results
# * Class CHAN-CON-AP
#   - Precision: 1.0
#   - Recall: 0.8
#   - F1: 0.888888888888889
#   - Total actual: 5
#   - Total predicted: 4
# * Class CHAN-WOR
#   - Precision: 0.42857142857142855
#   - Recall: 0.75
#   - F1: 0.5454545454545454
#   - Total actual: 4
#   - Total predicted: 7
# * Class CHAN-IMP
#   - Precision: 0.8571428571428571
#   - Recall: 1.0
#   - F1: 0.923076923076923
#   - Total actual: 6
#   - Total predicted: 7
# * Class CHAN-CON-RES
#   - Precision: 1.0
#   - Recall: 1.0
#   - F1: 1.0
#   - Total actual: 1
#   - Total predicted: 1
# * Class CHAN-NC
#   - Precision: 0.9090909090909091
#   - Recall: 0.8333333333333334
#   - F1: 0.8695652173913043
#   - Total actual: 60
#   - Total predicted: 55
# * Class CHAN-DEV-AP
#   - Precision: nan
#   - Recall: nan
#   - F1: nan
#   - Total actual: 0
#   - Total predicted: 0
# * Class CHAN-DEV-PLACE
#   - Precision: nan
#   - Recall: nan
#   - F1: nan
#   - Total actual: 0
#   - Total predicted: 0
# * Class CHAN-DEV-DISA
#   - Precision: 1.0
#   - Recall: 1.0
#   - F1: 1.0
#   - Total actual: 2
#   - Total predicted: 2
# * Class ANAT-DP
#   - Precision: 0.9591836734693877
#   - Recall: 0.9773156899810964
#   - F1: 0.9681647940074907
#   - Total actual: 529
#   - Total predicted: 539
# * Class OBS-DP
#   - Precision: 0.8963133640552995
#   - Recall: 0.8942528735632184
#   - F1: 0.8952819332566168
#   - Total actual: 435
#   - Total predicted: 434
# * Class OBS-U
#   - Precision: 0.7045454545454546
#   - Recall: 0.7560975609756098
#   - F1: 0.7294117647058823
#   - Total actual: 41
#   - Total predicted: 44
# * Class OBS-DA
#   - Precision: 0.9621848739495799
#   - Recall: 0.9581589958158996
#   - F1: 0.960167714884696
#   - Total actual: 239
#   - Total predicted: 238
# * Micro precision: 0.9256198347107438
# * Micro recall: 0.9319213313161876
# * Micro F1: 0.9287598944591029
# * Macro precision: 0.7264193800687431
# * Macro recall: 0.7474298711390964
# * Macro F1: 0.7316676484721957
#
# Relations results
# * Class modify
#   - Precision: 0.8287292817679558
#   - Recall: 0.774526678141136
#   - F1: 0.8007117437722421
#   - Total actual: 581
#   - Total predicted: 543
# * Class located_at
#   - Precision: 0.8096590909090909
#   - Recall: 0.8532934131736527
#   - F1: 0.8309037900874635
#   - Total actual: 334
#   - Total predicted: 352
# * Class suggestive_of
#   - Precision: 0.5384615384615384
#   - Recall: 0.5185185185185185
#   - F1: 0.5283018867924528
#   - Total actual: 27
#   - Total predicted: 26
# * Micro precision: 0.8132464712269273
# * Micro recall: 0.7951167728237792
# * Micro F1: 0.8040794417606012
# * Macro precision: 0.7256166370461951
# * Macro recall: 0.715446203277769
# * Macro F1: 0.7199724735507195
#
#
# ———————————————————[ Evaluating dygie-radgraph-pubmedbert ]———————————————————
# NER results
# * Class CHAN-CON-AP
#   - Precision: 1.0
#   - Recall: 0.8
#   - F1: 0.888888888888889
#   - Total actual: 5
#   - Total predicted: 4
# * Class CHAN-WOR
#   - Precision: 0.375
#   - Recall: 0.75
#   - F1: 0.5
#   - Total actual: 4
#   - Total predicted: 8
# * Class CHAN-IMP
#   - Precision: 0.8571428571428571
#   - Recall: 1.0
#   - F1: 0.923076923076923
#   - Total actual: 6
#   - Total predicted: 7
# * Class CHAN-CON-RES
#   - Precision: nan
#   - Recall: 0.0
#   - F1: nan
#   - Total actual: 1
#   - Total predicted: 0
# * Class CHAN-NC
#   - Precision: 0.8833333333333333
#   - Recall: 0.8833333333333333
#   - F1: 0.8833333333333333
#   - Total actual: 60
#   - Total predicted: 60
# * Class CHAN-DEV-AP
#   - Precision: nan
#   - Recall: nan
#   - F1: nan
#   - Total actual: 0
#   - Total predicted: 0
# * Class CHAN-DEV-PLACE
#   - Precision: nan
#   - Recall: nan
#   - F1: nan
#   - Total actual: 0
#   - Total predicted: 0
# * Class CHAN-DEV-DISA
#   - Precision: 1.0
#   - Recall: 1.0
#   - F1: 1.0
#   - Total actual: 2
#   - Total predicted: 2
# * Class ANAT-DP
#   - Precision: 0.9555555555555556
#   - Recall: 0.9754253308128544
#   - F1: 0.9653882132834425
#   - Total actual: 529
#   - Total predicted: 540
# * Class OBS-DP
#   - Precision: 0.9058823529411765
#   - Recall: 0.8850574712643678
#   - F1: 0.8953488372093024
#   - Total actual: 435
#   - Total predicted: 425
# * Class OBS-U
#   - Precision: 0.6571428571428571
#   - Recall: 0.5609756097560976
#   - F1: 0.605263157894737
#   - Total actual: 41
#   - Total predicted: 35
# * Class OBS-DA
#   - Precision: 0.9395161290322581
#   - Recall: 0.9748953974895398
#   - F1: 0.9568788501026695
#   - Total actual: 239
#   - Total predicted: 248
# * Micro precision: 0.9217456734386757
# * Micro recall: 0.926626323751891
# * Micro F1: 0.9241795548849491
# * Macro precision: 0.6311310904290032
# * Macro recall: 0.6524739285546827
# * Macro F1: 0.6348481836491081
#
# Relations results
# * Class modify
#   - Precision: 0.8455882352941176
#   - Recall: 0.7917383820998278
#   - F1: 0.8177777777777776
#   - Total actual: 581
#   - Total predicted: 544
# * Class located_at
#   - Precision: 0.8210227272727273
#   - Recall: 0.8652694610778443
#   - F1: 0.8425655976676386
#   - Total actual: 334
#   - Total predicted: 352
# * Class suggestive_of
#   - Precision: 0.6
#   - Recall: 0.6666666666666666
#   - F1: 0.631578947368421
#   - Total actual: 27
#   - Total predicted: 30
# * Micro precision: 0.82829373650108
# * Micro recall: 0.8142250530785563
# * Micro F1: 0.8211991434689507
# * Macro precision: 0.7555369875222816
# * Macro recall: 0.7745581699481129
# * Macro F1: 0.7639741076046125
# /home/ad461/miniconda3/envs/radgraph-env/lib/python3.7/site-packages/ipykernel_launcher.py:17: RuntimeWarning: invalid value encountered in double_scalars
# /home/ad461/miniconda3/envs/radgraph-env/lib/python3.7/site-packages/ipykernel_launcher.py:19: RuntimeWarning: invalid value encountered in double_scalars

# %% [markdown]
# ## CheXpert Only

# %%
for model in MODELS:
    evaluate(model, dataset=Datasets.CHEXPERT)
# Out:
# ———————————————————[ Evaluating dygie-radgraph-base ]———————————————————
# NER results
# * Class CHAN-CON-AP
#   - Precision: nan
#   - Recall: 0.0
#   - F1: nan
#   - Total actual: 1
#   - Total predicted: 0
# * Class CHAN-WOR
#   - Precision: 0.8
#   - Recall: 0.9411764705882353
#   - F1: 0.8648648648648648
#   - Total actual: 17
#   - Total predicted: 20
# * Class CHAN-IMP
#   - Precision: 1.0
#   - Recall: 1.0
#   - F1: 1.0
#   - Total actual: 5
#   - Total predicted: 5
# * Class CHAN-CON-RES
#   - Precision: nan
#   - Recall: nan
#   - F1: nan
#   - Total actual: 0
#   - Total predicted: 0
# * Class CHAN-NC
#   - Precision: 0.9344262295081968
#   - Recall: 0.8260869565217391
#   - F1: 0.8769230769230769
#   - Total actual: 69
#   - Total predicted: 61
# * Class CHAN-DEV-AP
#   - Precision: 1.0
#   - Recall: 0.4
#   - F1: 0.5714285714285715
#   - Total actual: 5
#   - Total predicted: 2
# * Class CHAN-DEV-PLACE
#   - Precision: 1.0
#   - Recall: 1.0
#   - F1: 1.0
#   - Total actual: 1
#   - Total predicted: 1
# * Class CHAN-DEV-DISA
#   - Precision: 1.0
#   - Recall: 1.0
#   - F1: 1.0
#   - Total actual: 5
#   - Total predicted: 5
# * Class ANAT-DP
#   - Precision: 0.9282371294851794
#   - Recall: 0.9282371294851794
#   - F1: 0.9282371294851794
#   - Total actual: 641
#   - Total predicted: 641
# * Class OBS-DP
#   - Precision: 0.8295254833040422
#   - Recall: 0.8692449355432781
#   - F1: 0.8489208633093526
#   - Total actual: 543
#   - Total predicted: 569
# * Class OBS-U
#   - Precision: 0.6666666666666666
#   - Recall: 0.723404255319149
#   - F1: 0.6938775510204082
#   - Total actual: 47
#   - Total predicted: 51
# * Class OBS-DA
#   - Precision: 0.9151515151515152
#   - Recall: 0.9041916167664671
#   - F1: 0.9096385542168675
#   - Total actual: 167
#   - Total predicted: 165
# * Micro precision: 0.8802631578947369
# * Micro recall: 0.8914057295136576
# * Micro F1: 0.8857994041708044
# * Macro precision: 0.7561672520096333
# * Macro recall: 0.7160284470186706
# * Macro F1: 0.7244908842706934
#
# Relations results
# * Class modify
#   - Precision: 0.6770691994572592
#   - Recall: 0.6522875816993464
#   - F1: 0.6644474034620506
#   - Total actual: 765
#   - Total predicted: 737
# * Class located_at
#   - Precision: 0.7717717717717718
#   - Recall: 0.7648809523809523
#   - F1: 0.7683109118086696
#   - Total actual: 336
#   - Total predicted: 333
# * Class suggestive_of
#   - Precision: 0.7560975609756098
#   - Recall: 0.4696969696969697
#   - F1: 0.5794392523364487
#   - Total actual: 66
#   - Total predicted: 41
# * Micro precision: 0.7083708370837084
# * Micro recall: 0.6743787489288775
# * Micro F1: 0.6909569798068481
# * Macro precision: 0.7349795107348802
# * Macro recall: 0.6289551679257562
# * Macro F1: 0.6707325225357229
#
#
# ———————————————————[ Evaluating dygie-radgraph-biobert ]———————————————————
# NER results
# * Class CHAN-CON-AP
#   - Precision: 0.0
#   - Recall: 0.0
#   - F1: nan
#   - Total actual: 1
#   - Total predicted: 2
# * Class CHAN-WOR
#   - Precision: 0.8095238095238095
#   - Recall: 1.0
#   - F1: 0.8947368421052632
#   - Total actual: 17
#   - Total predicted: 21
# * Class CHAN-IMP
#   - Precision: 0.7142857142857143
#   - Recall: 1.0
#   - F1: 0.8333333333333333
#   - Total actual: 5
#   - Total predicted: 7
# * Class CHAN-CON-RES
#   - Precision: nan
#   - Recall: nan
#   - F1: nan
#   - Total actual: 0
#   - Total predicted: 0
# * Class CHAN-NC
#   - Precision: 0.9516129032258065
#   - Recall: 0.855072463768116
#   - F1: 0.900763358778626
#   - Total actual: 69
#   - Total predicted: 62
# * Class CHAN-DEV-AP
#   - Precision: 0.3333333333333333
#   - Recall: 0.2
#   - F1: 0.25
#   - Total actual: 5
#   - Total predicted: 3
# * Class CHAN-DEV-PLACE
#   - Precision: nan
#   - Recall: 0.0
#   - F1: nan
#   - Total actual: 1
#   - Total predicted: 0
# * Class CHAN-DEV-DISA
#   - Precision: 1.0
#   - Recall: 1.0
#   - F1: 1.0
#   - Total actual: 5
#   - Total predicted: 5
# * Class ANAT-DP
#   - Precision: 0.947452229299363
#   - Recall: 0.9282371294851794
#   - F1: 0.9377462568951931
#   - Total actual: 641
#   - Total predicted: 628
# * Class OBS-DP
#   - Precision: 0.790893760539629
#   - Recall: 0.8637200736648251
#   - F1: 0.8257042253521126
#   - Total actual: 543
#   - Total predicted: 593
# * Class OBS-U
#   - Precision: 0.5522388059701493
#   - Recall: 0.7872340425531915
#   - F1: 0.649122807017544
#   - Total actual: 47
#   - Total predicted: 67
# * Class OBS-DA
#   - Precision: 0.9565217391304348
#   - Recall: 0.9221556886227545
#   - F1: 0.9390243902439025
#   - Total actual: 167
#   - Total predicted: 161
# * Micro precision: 0.8663653970303422
# * Micro recall: 0.894070619586942
# * Micro F1: 0.8799999999999999
# * Macro precision: 0.58798852460902
# * Macro recall: 0.629701616507839
# * Macro F1: 0.6025359344771646
#
# Relations results
# * Class modify
#   - Precision: 0.720863309352518
#   - Recall: 0.677027027027027
#   - F1: 0.6982578397212543
#   - Total actual: 740
#   - Total predicted: 695
# * Class located_at
#   - Precision: 0.7360248447204969
#   - Recall: 0.75
#   - F1: 0.74294670846395
#   - Total actual: 316
#   - Total predicted: 322
# * Class suggestive_of
#   - Precision: 0.8666666666666667
# /home/ad461/miniconda3/envs/radgraph-env/lib/python3.7/site-packages/ipykernel_launcher.py:17: RuntimeWarning: invalid value encountered in double_scalars
# /home/ad461/miniconda3/envs/radgraph-env/lib/python3.7/site-packages/ipykernel_launcher.py:19: RuntimeWarning: invalid value encountered in double_scalars
# /home/ad461/miniconda3/envs/radgraph-env/lib/python3.7/site-packages/ipykernel_launcher.py:21: RuntimeWarning: invalid value encountered in double_scalars
#   - Recall: 0.6190476190476191
#   - F1: 0.7222222222222222
#   - Total actual: 63
#   - Total predicted: 45
# * Micro precision: 0.731638418079096
# * Micro recall: 0.6943699731903485
# * Micro F1: 0.7125171939477304
# * Macro precision: 0.7745182735798939
# * Macro recall: 0.6820248820248821
# * Macro F1: 0.7211422568024756
#
#
# ———————————————————[ Evaluating dygie-radgraph-bioclinicalbert ]———————————————————
# NER results
# * Class CHAN-CON-AP
#   - Precision: nan
#   - Recall: 0.0
#   - F1: nan
#   - Total actual: 1
#   - Total predicted: 0
# * Class CHAN-WOR
#   - Precision: 0.8095238095238095
#   - Recall: 1.0
#   - F1: 0.8947368421052632
#   - Total actual: 17
#   - Total predicted: 21
# * Class CHAN-IMP
#   - Precision: 1.0
#   - Recall: 1.0
#   - F1: 1.0
#   - Total actual: 5
#   - Total predicted: 5
# * Class CHAN-CON-RES
#   - Precision: nan
#   - Recall: nan
#   - F1: nan
#   - Total actual: 0
#   - Total predicted: 0
# * Class CHAN-NC
#   - Precision: 0.9242424242424242
#   - Recall: 0.8840579710144928
#   - F1: 0.9037037037037037
#   - Total actual: 69
#   - Total predicted: 66
# * Class CHAN-DEV-AP
#   - Precision: 1.0
#   - Recall: 0.4
#   - F1: 0.5714285714285715
#   - Total actual: 5
#   - Total predicted: 2
# * Class CHAN-DEV-PLACE
#   - Precision: nan
#   - Recall: 0.0
#   - F1: nan
#   - Total actual: 1
#   - Total predicted: 0
# * Class CHAN-DEV-DISA
#   - Precision: 1.0
#   - Recall: 1.0
#   - F1: 1.0
#   - Total actual: 5
#   - Total predicted: 5
# * Class ANAT-DP
#   - Precision: 0.9477848101265823
#   - Recall: 0.9344773790951638
#   - F1: 0.9410840534171249
#   - Total actual: 641
#   - Total predicted: 632
# * Class OBS-DP
#   - Precision: 0.9
#   - Recall: 0.861878453038674
#   - F1: 0.8805268109125118
#   - Total actual: 543
#   - Total predicted: 520
# * Class OBS-U
#   - Precision: 0.6440677966101694
#   - Recall: 0.8085106382978723
#   - F1: 0.7169811320754716
#   - Total actual: 47
#   - Total predicted: 59
# * Class OBS-DA
#   - Precision: 0.950920245398773
#   - Recall: 0.9281437125748503
#   - F1: 0.9393939393939393
#   - Total actual: 167
#   - Total predicted: 163
# * Micro precision: 0.9164969450101833
# * Micro recall: 0.899400399733511
# * Micro F1: 0.9078681909885676
# * Macro precision: 0.6813782571584799
# * Macro recall: 0.6514223461684211
# * Macro F1: 0.6539879210863823
#
# Relations results
# * Class modify
#   - Precision: 0.7655068078668684
#   - Recall: 0.661437908496732
#   - F1: 0.7096774193548386
#   - Total actual: 765
#   - Total predicted: 661
# * Class located_at
#   - Precision: 0.7787878787878788
#   - Recall: 0.7648809523809523
#   - F1: 0.7717717717717717
#   - Total actual: 336
#   - Total predicted: 330
# * Class suggestive_of
#   - Precision: 0.7547169811320755
#   - Recall: 0.6060606060606061
#   - F1: 0.6722689075630252
#   - Total actual: 66
#   - Total predicted: 53
# * Micro precision: 0.7691570881226054
# * Micro recall: 0.68808911739503
# * Micro F1: 0.7263681592039802
# * Macro precision: 0.7663372225956074
# * Macro recall: 0.6774598223127635
# * Macro F1: 0.7179060328965452
#
#
# ———————————————————[ Evaluating dygie-radgraph-bluebert ]———————————————————
# NER results
# * Class CHAN-CON-AP
#   - Precision: nan
#   - Recall: 0.0
#   - F1: nan
#   - Total actual: 1
#   - Total predicted: 0
# * Class CHAN-WOR
#   - Precision: 0.8
#   - Recall: 0.9411764705882353
#   - F1: 0.8648648648648648
#   - Total actual: 17
#   - Total predicted: 20
# * Class CHAN-IMP
#   - Precision: 0.8333333333333334
#   - Recall: 1.0
#   - F1: 0.9090909090909091
#   - Total actual: 5
#   - Total predicted: 6
# * Class CHAN-CON-RES
#   - Precision: nan
#   - Recall: nan
#   - F1: nan
#   - Total actual: 0
#   - Total predicted: 0
# * Class CHAN-NC
#   - Precision: 0.9
#   - Recall: 0.9130434782608695
#   - F1: 0.9064748201438848
#   - Total actual: 69
#   - Total predicted: 70
# * Class CHAN-DEV-AP
#   - Precision: 1.0
#   - Recall: 0.8
#   - F1: 0.888888888888889
#   - Total actual: 5
#   - Total predicted: 4
# * Class CHAN-DEV-PLACE
#   - Precision: nan
#   - Recall: 0.0
#   - F1: nan
#   - Total actual: 1
#   - Total predicted: 0
# * Class CHAN-DEV-DISA
#   - Precision: 1.0
#   - Recall: 0.8
#   - F1: 0.888888888888889
#   - Total actual: 5
#   - Total predicted: 4
# * Class ANAT-DP
#   - Precision: 0.939297124600639
#   - Recall: 0.9173166926677067
#   - F1: 0.9281767955801105
#   - Total actual: 641
#   - Total predicted: 626
# * Class OBS-DP
#   - Precision: 0.8117443868739206
#   - Recall: 0.8655616942909761
#   - F1: 0.8377896613190731
#   - Total actual: 543
#   - Total predicted: 579
# * Class OBS-U
#   - Precision: 0.47674418604651164
#   - Recall: 0.8723404255319149
#   - F1: 0.6165413533834587
#   - Total actual: 47
#   - Total predicted: 86
# * Class OBS-DA
#   - Precision: 0.8735632183908046
#   - Recall: 0.9101796407185628
#   - F1: 0.8914956011730205
#   - Total actual: 167
#   - Total predicted: 174
# * Micro precision: 0.8559592096876991
# * Micro recall: 0.8947368421052632
# * Micro F1: 0.8749185667752442
# * Macro precision: 0.6362235207704341
# * Macro recall: 0.6683015335048554
# * Macro F1: 0.644350981944425
#
# Relations results
# * Class modify
#   - Precision: 0.6732117812061711
#   - Recall: 0.6274509803921569
#   - F1: 0.6495263870094722
#   - Total actual: 765
#   - Total predicted: 713
# * Class located_at
#   - Precision: 0.7314285714285714
#   - Recall: 0.7619047619047619
#   - F1: 0.7463556851311954
#   - Total actual: 336
#   - Total predicted: 350
# * Class suggestive_of
#   - Precision: 0.7083333333333334
#   - Recall: 0.5151515151515151
#   - F1: 0.5964912280701754
#   - Total actual: 66
#   - Total predicted: 48
# * Micro precision: 0.693069306930693
# * Micro recall: 0.6598114824335904
# * Micro F1: 0.6760316066725197
# * Macro precision: 0.7043245619893587
# * Macro recall: 0.6348357524828113
# * Macro F1: 0.6641244334036144
#
#
# ———————————————————[ Evaluating dygie-radgraph-pubmedbert ]———————————————————
# NER results
# * Class CHAN-CON-AP
#   - Precision: 0.0
#   - Recall: 0.0
#   - F1: nan
#   - Total actual: 1
#   - Total predicted: 2
# * Class CHAN-WOR
#   - Precision: 0.5517241379310345
#   - Recall: 0.9411764705882353
#   - F1: 0.6956521739130435
#   - Total actual: 17
#   - Total predicted: 29
# * Class CHAN-IMP
#   - Precision: 1.0
#   - Recall: 0.8
#   - F1: 0.888888888888889
#   - Total actual: 5
#   - Total predicted: 4
# * Class CHAN-CON-RES
#   - Precision: 0.0
#   - Recall: nan
#   - F1: nan
#   - Total actual: 0
#   - Total predicted: 1
# * Class CHAN-NC
#   - Precision: 0.927536231884058
#   - Recall: 0.927536231884058
#   - F1: 0.927536231884058
#   - Total actual: 69
#   - Total predicted: 69
# * Class CHAN-DEV-AP
#   - Precision: 0.0
#   - Recall: 0.0
#   - F1: nan
#   - Total actual: 5
#   - Total predicted: 1
# * Class CHAN-DEV-PLACE
#   - Precision: nan
#   - Recall: 0.0
#   - F1: nan
#   - Total actual: 1
#   - Total predicted: 0
# * Class CHAN-DEV-DISA
#   - Precision: 1.0
#   - Recall: 1.0
#   - F1: 1.0
#   - Total actual: 5
#   - Total predicted: 5
# * Class ANAT-DP
#   - Precision: 0.9554848966613673
#   - Recall: 0.9375975039001561
#   - F1: 0.946456692913386
#   - Total actual: 641
#   - Total predicted: 629
# * Class OBS-DP
#   - Precision: 0.6122715404699739
#   - Recall: 0.8637200736648251
#   - F1: 0.7165775401069517
#   - Total actual: 543
#   - Total predicted: 766
# * Class OBS-U
#   - Precision: 0.6379310344827587
#   - Recall: 0.7872340425531915
#   - F1: 0.7047619047619048
#   - Total actual: 47
#   - Total predicted: 58
# * Class OBS-DA
#   - Precision: 0.94375
#   - Recall: 0.9041916167664671
#   - F1: 0.9235474006116209
#   - Total actual: 167
#   - Total predicted: 160
# * Micro precision: 0.781322505800464
# * Micro recall: 0.8974017321785477
# * Micro F1: 0.8353488372093023
# * Macro precision: 0.5523914867857661
# * Macro recall: 0.5967879949464111
# * Macro F1: 0.566951736089988
#
# Relations results
# * Class modify
#   - Precision: 0.6582125603864735
#   - Recall: 0.7124183006535948
#   - F1: 0.6842435655994977
#   - Total actual: 765
#   - Total predicted: 828
# * Class located_at
#   - Precision: 0.7925696594427245
#   - Recall: 0.7619047619047619
#   - F1: 0.7769347496206374
#   - Total actual: 336
#   - Total predicted: 323
# * Class suggestive_of
#   - Precision: 0.7254901960784313
#   - Recall: 0.5606060606060606
#   - F1: 0.6324786324786323
#   - Total actual: 66
#   - Total predicted: 51
# * Micro precision: 0.697171381031614
# * Micro recall: 0.7180805484147387
# * Micro F1: 0.7074715069649641
# * Macro precision: 0.7254241386358764
# * Macro recall: 0.6783097077214725
# * Macro F1: 0.6978856492329225
